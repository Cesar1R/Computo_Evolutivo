# %%
cant_puntos = [1000000, 2000000, 3000000, 4000000, 5000000]

promedios_aleatorios = {
    'Cuadratico2D' :    [4.49324,       11.4858,    19.8313,    28.3564,    38.78],  
    'Scan2D':           [0.680587,      1.43033,    2.19715,    2.97883,    3.77931], 
    'D&C2D':            [2.53361,       5.17666,    7.96812,    10.5759,    13.4679],
    'Scan3D' :          [0.558774,      1.23847,    1.98856,    2.75088,    3.5112],
    'D&C3D':            [2.65263,       5.40768,    8.1957,     11.0374,    13.9077,], 
'Cuadratico3D':     [14.1315,       35.2048,        61.2959,    89.3464,    114.663 ],
     
}

# %%
import matplotlib.pyplot as plt 
import numpy as np 

def fun (x): 
    return x * np.log(x)

complejidad_6 = [fun(x)/(10e6 * 1.5)    for x in cant_puntos ]
complejidad_5 = [fun(x)/(10e5 * 5) for x in cant_puntos ]
complejidad_cuadratica = [x**2/(10e10 * 5) for x in cant_puntos]

plt.figure(figsize=(10, 6))

plt.plot(cant_puntos, promedios_aleatorios['Scan2D'], label ="SCAN")
plt.plot(cant_puntos, promedios_aleatorios['Cuadratico2D'], label = "Cuadratico")
plt.plot(cant_puntos, promedios_aleatorios['D&C2D'], label = "Divide y venceras")
plt.plot(cant_puntos, complejidad_6, linestyle=':', label = 'n * log_2(n) /( 10^6 * 1.5)')
plt.plot(cant_puntos, complejidad_5, linestyle='--', label = 'n*log_2(n)/ (10^5 * 5) ')
plt.plot(cant_puntos, complejidad_cuadratica,  linestyle='dashdot', label = 'n^2 / (10e10* 1.5)')
plt.legend()
plt.xlabel("Cantidad de puntos")
plt.ylabel("Tiempo de ejecucion en segundos")
plt.xticks(cant_puntos)
plt.grid(True)
plt.show()

# %%
def fun (x): 
    return x * np.log(x)

complejidad_6 = [fun(x)/(10e6 * 1.5)    for x in cant_puntos ]
complejidad_5 = [fun(x)/(10e5 * 5) for x in cant_puntos ]
complejidad_cuadratica = [x**2/(10e10 *2) for x in cant_puntos]

plt.figure(figsize=(10, 6))

plt.plot(cant_puntos, promedios_aleatorios['Scan3D'], label ="SCAN")
plt.plot(cant_puntos, promedios_aleatorios['Cuadratico3D'], label = "Cuadratico")
plt.plot(cant_puntos, promedios_aleatorios['D&C3D'], label = "Divide y venceras")
plt.plot(cant_puntos, complejidad_6, linestyle=':', label = 'n * log_2(n) /( 10^6 * 1.5)')
plt.plot(cant_puntos, complejidad_5, linestyle='--', label = 'n*log_2(n)/ (10^5 * 5) ')
plt.plot(cant_puntos, complejidad_cuadratica, linestyle='dashdot', label = 'n^2 / (10e10* 1.5)')
plt.legend()
plt.xlabel("Cantidad de puntos")
plt.ylabel("Tiempo de ejecucion en segundos")
plt.xticks(cant_puntos)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Domiandos

# %%
promedios_peorCaso = {
    'Cuadratico2D' :    [0.459532,      1.57262,    3.49981,    6.22354,    9.7446],  
    'Scan2D':           [0.00113848,    0.00252255, 0.00371083, 0.00531239, 0.00641947],
    'D&C2D':            [0.00505146,    0.0105048,  0.014813,   0.0208436,  0.0259318], 
    'Scan3D' :          [0.00143357,    0.00307372, 0.00477097, 0.00643095, 0.00824291], #
    'D&C3D':            [0.00362129,    0.00718877, 0.0111533,  0.0145718,  0.0186486], #
    'Cuadratico3D':     [0.611759,      2.08223,    4.61472,    8.05227,    12.1793],
}

# %%
import matplotlib.pyplot as plt 
import numpy as np 

cant_puntos = [10000, 20000, 30000, 40000, 50000]

def fun (x): 
    return x * np.log(x)

complejidad_6 = [fun(x)/(10e6 * 2) for x in cant_puntos ]
complejidad_5 = [fun(x)/(10e6 * 7) for x in cant_puntos ]
complejidad_cuadratica = [x**2/(10e11*2.5) for x in cant_puntos]

plt.figure(figsize=(10, 6))

plt.plot(cant_puntos, promedios_peorCaso['Scan2D'], label ="SCAN")
plt.plot(cant_puntos, promedios_peorCaso['Cuadratico2D'], label = "Cuadratico")
plt.plot(cant_puntos, promedios_peorCaso['D&C2D'], label = "Divide y venceras")
plt.plot(cant_puntos, complejidad_6, linestyle=':', label = 'n * log_2(n) /(10e8 * 2.7)')
plt.plot(cant_puntos, complejidad_5, linestyle='--', label = 'n*log_2(n)/ (10e8 * 9)')
plt.plot(cant_puntos, complejidad_cuadratica,  linestyle='dashdot', label = 'n^2 / (10e11*2.5)')
plt.legend()
plt.xlabel("Cantidad de puntos")
plt.ylabel("Tiempo de ejecucion en segundos")
plt.xticks(cant_puntos)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 



def fun (x): 
    return x * np.log(x)

complejidad_6 = [fun(x)/(10e6 * 2) for x in cant_puntos ]
complejidad_5 = [fun(x)/(10e6 * 7) for x in cant_puntos ]

plt.figure(figsize=(10, 6))

plt.plot(cant_puntos, promedios_peorCaso['Scan2D'], label ="SCAN")
plt.plot(cant_puntos, promedios_peorCaso['D&C2D'], label = "Divide y venceras")
plt.plot(cant_puntos, complejidad_6, linestyle=':', label = 'n * log_2(n) /(10e8 * 2.7)')
plt.plot(cant_puntos, complejidad_5, linestyle='--', label = 'n*log_2(n)/ (10e8 * 9)')
plt.legend()
plt.xlabel("Cantidad de puntos")
plt.ylabel("Tiempo de ejecucion en segundos")
plt.xticks(cant_puntos)
plt.grid(True)
plt.show()

# %%
def fun (x): 
    return x * np.log(x)
complejidad_6 = [fun(x)/(10e8*9.1 )    for x in cant_puntos ]
complejidad_5 = [fun(x)/(10e8 * 4) for x in cant_puntos ]

complejidad_cuadratica = [x**2/(10e7 *1.9) for x in cant_puntos]

plt.figure(figsize=(10, 6))

plt.plot(cant_puntos, promedios_peorCaso['Scan3D'], label ="SCAN")
plt.plot(cant_puntos, promedios_peorCaso['Cuadratico3D'], label = "Cuadratico")
plt.plot(cant_puntos, promedios_peorCaso['D&C3D'], label = "Divide y venceras")
plt.plot(cant_puntos, complejidad_6, linestyle=':', label = 'n * log_2(n) /(10e8*9.1 ) ')
plt.plot(cant_puntos, complejidad_5, linestyle='--', label = 'n*log_2(n)/ (10e8 * 4) ')
plt.plot(cant_puntos, complejidad_cuadratica, linestyle='dashdot', label = 'n^2 / (10e11 *1.9)')
plt.legend()
plt.xlabel("Cantidad de puntos")
plt.ylabel("Tiempo de ejecucion en segundos")
plt.xticks(cant_puntos)
plt.grid(True)
plt.show()

# %%
def fun (x): 
    return x * np.log(x)
complejidad_6 = [fun(x)/(10e6*6)    for x in cant_puntos ]
complejidad_5 = [fun(x)/(10e6 * 2.7) for x in cant_puntos ]

plt.figure(figsize=(10, 6))

plt.plot(cant_puntos, promedios_peorCaso['Scan3D'], label ="SCAN")
plt.plot(cant_puntos, promedios_peorCaso['D&C3D'], label = "Divide y venceras")
plt.plot(cant_puntos, complejidad_6, linestyle=':', label = 'n * log_2(n) /(10e8*9.1 ) ')
plt.plot(cant_puntos, complejidad_5, linestyle='--', label = 'n*log_2(n)/ (10e8 * 4) ')
plt.legend()
plt.xlabel("Cantidad de puntos")
plt.ylabel("Tiempo de ejecucion en segundos")
plt.xticks(cant_puntos)
plt.grid(True)
plt.show()
